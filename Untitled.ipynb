# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('high_salary.train.csv')
df.head()
# Out:
#       id  social-security-number  house-number  age-group     workclass  \
# 0   8616             830617145.0        8732.0        2.0  self-emp-inc
# 1  21982             151595184.0        1894.0        3.0     local-gov
# 2  11191             303184281.0        9466.0        0.0       private
# 3  22229             369287837.0        8511.0        2.0       private
# 4  20732             420084973.0        1281.0        3.0       private
#
#      fnlwgt  education  education-num      marital-status         occupation  \
# 0  270079.0  bachelors           13.0  married-civ-spouse    exec-managerial
# 1  146325.0  doctorate           16.0  married-civ-spouse     prof-specialty
# 2  240767.0    hs-grad            9.0       never-married      other-service
# 3  118536.0    hs-grad            9.0            divorced  machine-op-inspct
# 4  160440.0  bachelors           13.0  married-civ-spouse              sales
#
#      relationship   race     sex  capitalgain  capitalloss  hoursperweek  \
# 0         husband  white    male          0.0          0.0           3.0
# 1         husband  white    male          0.0          2.0           2.0
# 2   not-in-family  white  female          0.0          0.0           1.0
# 3  other-relative  black    male          0.0          0.0           2.0
# 4         husband  white    male          0.0          0.0           3.0
#
#   native-country-code native-country  label
# 0                 USA  united-states    1.0
# 1                 USA  united-states    1.0
# 2                 USA  united-states    0.0
# 3                 USA  united-states    0.0
# 4                 USA  united-states    1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20900 entries, 0 to 20899
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      20900 non-null  int64
#  1   social-security-number  20886 non-null  float64
#  2   house-number            20873 non-null  float64
#  3   age-group               20887 non-null  float64
#  4   workclass               19843 non-null  object
#  5   fnlwgt                  20877 non-null  float64
#  6   education               20880 non-null  object
#  7   education-num           20886 non-null  float64
#  8   marital-status          20877 non-null  object
#  9   occupation              19846 non-null  object
#  10  relationship            20879 non-null  object
#  11  race                    20878 non-null  object
#  12  sex                     20878 non-null  object
#  13  capitalgain             20877 non-null  float64
#  14  capitalloss             20879 non-null  float64
#  15  hoursperweek            20879 non-null  float64
#  16  native-country-code     20501 non-null  object
#  17  native-country          20502 non-null  object
#  18  label                   20900 non-null  float64
# dtypes: float64(9), int64(1), object(9)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#                  id  social-security-number  house-number     age-group  \
# count  20900.000000            2.088600e+04   20873.00000  20887.000000
# mean   13949.186842            5.509897e+08    5053.09553      1.910327
# std     8039.004999            2.603583e+08    2863.89731      1.251276
# min        0.000000            1.000659e+08     101.00000      0.000000
# 25%     6987.750000            3.209004e+08    2602.00000      1.000000
# 50%    13974.500000            5.521493e+08    5011.00000      2.000000
# 75%    20877.250000            7.770986e+08    7554.00000      3.000000
# max    27866.000000            9.999588e+08    9998.00000      4.000000
#
#              fnlwgt  education-num   capitalgain   capitalloss  hoursperweek  \
# count  2.087700e+04   20886.000000  20877.000000  20879.000000  20879.000000
# mean   1.891310e+05      10.457483      0.306893      0.150821      2.042387
# std    1.033706e+05       2.607752      0.939457      0.643003      0.877044
# min    1.376900e+04       1.000000      0.000000      0.000000      0.000000
# 25%    1.178490e+05       9.000000      0.000000      0.000000      2.000000
# 50%    1.779450e+05      10.000000      0.000000      0.000000      2.000000
# 75%    2.367690e+05      13.000000      0.000000      0.000000      3.000000
# max    1.226583e+06      16.000000      4.000000      4.000000      4.000000
#
#               label
# count  20900.000000
# mean       0.419378
# std        0.493469
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X = df[['age-group']]
y = df['label']

test_size = 0.3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

# %%
imputer = SimpleImputer(strategy='mean')

# %%
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train_imputed, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train_imputed, y_train)
# Out:
# 0.6123718386876281

# %%
model.intercept_
# Out:
# array([-1.33663688])

# %%
model.coef_
# Out:
# array([[0.50836055]])

# %%
X_test
# Out:
#        age-group
# 7194         2.0
# 19665        3.0
# 14709        1.0
# 14860        2.0
# 20586        1.0
# ...          ...
# 16492        3.0
# 17522        2.0
# 17556        1.0
# 10618        2.0
# 20806        4.0
#
# [6270 rows x 1 columns]

# %%
predicted = model.predict(X_test_imputed)
predicted
# Out:
# array([0., 1., 0., ..., 0., 0., 1.])

# %%
y_test.values
# Out:
# array([1., 0., 0., ..., 0., 0., 1.])

# %%
model.predict_proba(X_test_imputed)
# Out:
# array([[0.57930373, 0.42069627],
#        [0.45302773, 0.54697227],
#        [0.69599035, 0.30400965],
#        ...,
#        [0.69599035, 0.30400965],
#        [0.57930373, 0.42069627],
#        [0.33252091, 0.66747909]])
